# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from datetime import datetime

clean_data = Path(r"..\Resources\cleaned_netflix_df.csv")

netflix_data_df = pd.read_csv(clean_data)

netflix_data_df.head()
# Out:
#    Unnamed: 0     type                                            country  \
# 0           0    Movie                                      United States
# 1           1  TV Show                                       South Africa
# 2           4  TV Show                                              India
# 3           7    Movie  United States, Ghana, Burkina Faso, United Kin...
# 4           8  TV Show                                     United Kingdom
#
#            date_added  release_year rating  \
# 0  September 25, 2021          2020  PG-13
# 1  September 24, 2021          2021  TV-MA
# 2  September 24, 2021          2021  TV-MA
# 3  September 24, 2021          1993  TV-MA
# 4  September 24, 2021          2021  TV-14
#
#                                            listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  International TV Shows, Romantic TV Shows, TV ...
# 3   Dramas, Independent Movies, International Movies
# 4                       British TV Shows, Reality TV

# %%
#netflix_data_df['date_added'] = pd.to_datetime(netflix_data_df['date_added'])
netflix_data_df['date_added'] = pd.to_datetime(netflix_data_df['date_added'], format="%B %d, %Y", errors='coerce')

# %%
netflix_data_df['year_added'] = netflix_data_df['date_added'].dt.year
netflix_data_df['month_added'] = netflix_data_df['date_added'].dt.month_name()

# %%
release_counts = netflix_data_df.groupby(['year_added', 'month_added']).size().reset_index(name='count')

release_counts
# Out:
#      year_added month_added  count
# 0        2008.0    February      1
# 1        2008.0     January      1
# 2        2009.0         May      1
# 3        2009.0    November      1
# 4        2010.0    November      1
# ..          ...         ...    ...
# 102      2021.0        July    162
# 103      2021.0        June    147
# 104      2021.0       March     98
# 105      2021.0         May     97
# 106      2021.0   September    126
#
# [107 rows x 3 columns]

# %%
#plt.figure(figsize=(12, 6))
#plt.plot(release_counts['year_added'].astype(str) + ' ' + release_counts['month_added'], release_counts['count'], marker='o')
#plt.title('Netflix Content Releasement Over Time')
#plt.xlabel('Month and Year')
#plt.ylabel('Number of Releases')
#plt.xticks(rotation=45)
#plt.tight_layout()
#plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(release_counts['year_added'], release_counts['count'], marker='o')
plt.title('Netflix Content Releasement Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(release_counts['year_added'], release_counts['count'])
plt.title('Netflix Content Releasement Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(release_counts['month_added'], release_counts['count'], marker='o')
plt.title('Netflix Content Releasement Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(release_counts['month_added'], release_counts['count'])
plt.title('Netflix Content Releasement Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
