# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load
netflix_titles_to_load = Path("Resources/netflix_titles.csv")

# Read file and store into Pandas DataFrame
orig_netflix_titles_df = pd.read_csv(netflix_titles_to_load)
orig_netflix_titles_df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
orig_netflix_titles_df = orig_netflix_titles_df.drop_duplicates()
orig_netflix_titles_df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
orig_netflix_titles_df = orig_netflix_titles_df.drop(columns=["show_id", "title", "director", "cast", "duration", "description"])
orig_netflix_titles_df
# Out:
#          type        country          date_added  release_year rating  \
# 0       Movie  United States  September 25, 2021          2020  PG-13
# 1     TV Show   South Africa  September 24, 2021          2021  TV-MA
# 2     TV Show            NaN  September 24, 2021          2021  TV-MA
# 3     TV Show            NaN  September 24, 2021          2021  TV-MA
# 4     TV Show          India  September 24, 2021          2021  TV-MA
# ...       ...            ...                 ...           ...    ...
# 8802    Movie  United States   November 20, 2019          2007      R
# 8803  TV Show            NaN        July 1, 2019          2018  TV-Y7
# 8804    Movie  United States    November 1, 2019          2009      R
# 8805    Movie  United States    January 11, 2020          2006     PG
# 8806    Movie          India       March 2, 2019          2015  TV-14
#
#                                               listed_in
# 0                                         Documentaries
# ...

# %%
orig_netflix_titles_df = orig_netflix_titles_df.dropna(subset=["country"])
orig_netflix_titles_df
# Out:
#          type                                            country  \
# 0       Movie                                      United States
# 1     TV Show                                       South Africa
# 4     TV Show                                              India
# 7       Movie  United States, Ghana, Burkina Faso, United Kin...
# 8     TV Show                                     United Kingdom
# ...       ...                                                ...
# 8801    Movie                       United Arab Emirates, Jordan
# 8802    Movie                                      United States
# 8804    Movie                                      United States
# 8805    Movie                                      United States
# 8806    Movie                                              India
#
#               date_added  release_year rating  \
# 0     September 25, 2021          2020  PG-13
# 1     September 24, 2021          2021  TV-MA
# ...

# %%
orig_netflix_titles_df = orig_netflix_titles_df.dropna()
orig_netflix_titles_df
# Out:
#          type                                            country  \
# 0       Movie                                      United States
# 1     TV Show                                       South Africa
# 4     TV Show                                              India
# 7       Movie  United States, Ghana, Burkina Faso, United Kin...
# 8     TV Show                                     United Kingdom
# ...       ...                                                ...
# 8801    Movie                       United Arab Emirates, Jordan
# 8802    Movie                                      United States
# 8804    Movie                                      United States
# 8805    Movie                                      United States
# 8806    Movie                                              India
#
#               date_added  release_year rating  \
# 0     September 25, 2021          2020  PG-13
# 1     September 24, 2021          2021  TV-MA
# ...

# %%
orig_netflix_titles_df.to_csv("Resources/cleaned_netflix_df.csv")
